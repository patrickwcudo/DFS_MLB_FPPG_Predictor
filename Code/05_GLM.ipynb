# %% [markdown]
# Will use a generalized linear model in this notebook.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm

from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Batter

# %%
# read in batter training data
batter_train = pd.read_csv('../Modeling_Data/batter_data_modeling.csv')
# read in batter testing data
batter_test = pd.read_csv('../Modeling_Data/batter_test_data.csv')

# %%
# set up X and y from training data
X = batter_train.drop(columns=['Name', 'Team', 'POS', 'PTS', 'FPPG'])
y = batter_train['FPPG']

# %%
# add constant to X
X = sm.add_constant(X)

# %%
# scale data
sc = StandardScaler()
# fit and transform X
X_sc = sc.fit_transform(X)

# %%
# GLM
glm_batter = sm.GLM(y, X_sc, family=sm.families.Poisson(link=sm.families.links.log())).fit()

# %%
results_summary = glm_batter.summary()

# %%
glm_batter.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   FPPG   No. Observations:                  635
# Model:                            GLM   Df Residuals:                      620
# Model Family:                 Poisson   Df Model:                           14
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -4191.5
# Date:                Mon, 10 May 2021   Deviance:                       6050.3
# Time:                        17:49:45   Pearson chi2:                 7.01e+04
# No. Iterations:                   100
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const               0          0        nan        nan           0           0
# x1            -0.4131      0.116     -3.562      0.000      -0.640      -0.186
# x2             4.8106      0.224     21.475      0.000       4.372       5.250
# x3             0.2101      0.117      1.802      0.072      -0.018       0.439
# x4            -2.2638      0.138    -16.399      0.000      -2.534      -1.993
# x5            -0.1267      0.065     -1.942      0.052      -0.255       0.001
# x6            -0.0595      0.024     -2.443      0.015      -0.107      -0.012
# x7            -0.3109      0.080     -3.887      0.000      -0.468      -0.154
# x8             0.1884      0.092      2.045      0.041       0.008       0.369
# x9            -0.6248      0.063     -9.908      0.000      -0.748      -0.501
# x10            0.0655      0.052      1.265      0.206      -0.036       0.167
# x11            0.0789      0.031      2.519      0.012       0.018       0.140
# x12           -0.0605      0.034     -1.804      0.071      -0.126       0.005
# x13           -1.3953      0.072    -19.333      0.000      -1.537      -1.254
# x14           -0.0731      0.080     -0.918      0.359      -0.229       0.083
# x15            1.2543      0.101     12.427      0.000       1.056       1.452
# x16            0.2456      0.038      6.465      0.000       0.171       0.320
# x17            0.6350      0.015     41.440      0.000       0.605       0.665
# x18            0.4493      0.026     17.511      0.000       0.399       0.500
# ==============================================================================
# """

# %%
# create data frame of coefficients
# save as html
results_as_html = results_summary.tables[1].as_html()
# read in html
results_df = pd.read_html(results_as_html, header=0, index_col=0)[0]
# set index from X columns
results_df['Features'] = X.columns
results_df.set_index('Features', inplace=True)

# %%
# sort values
results_df.sort_values(by='coef')
# Out:
#             coef  std err       z  P>|z|  [0.025  0.975]
# Features
# H        -2.2638    0.138 -16.399  0.000  -2.534  -1.993
# TB       -1.3953    0.072 -19.333  0.000  -1.537  -1.254
# BB       -0.6248    0.063  -9.908  0.000  -0.748  -0.501
# GMS      -0.4131    0.116  -3.562  0.000  -0.640  -0.186
# HR       -0.3109    0.080  -3.887  0.000  -0.468  -0.154
# 2B       -0.1267    0.065  -1.942  0.052  -0.255   0.001
# AVG      -0.0731    0.080  -0.918  0.359  -0.229   0.083
# CS       -0.0605    0.034  -1.804  0.071  -0.126   0.005
# 3B       -0.0595    0.024  -2.443  0.015  -0.107  -0.012
# const     0.0000    0.000     NaN    NaN   0.000   0.000
# SO        0.0655    0.052   1.265  0.206  -0.036   0.167
# SB        0.0789    0.031   2.519  0.012   0.018   0.140
# RBI       0.1884    0.092   2.045  0.041   0.008   0.369
# R         0.2101    0.117   1.802  0.072  -0.018   0.439
# SLG       0.2456    0.038   6.465  0.000   0.171   0.320
# ISO       0.4493    0.026  17.511  0.000   0.399   0.500
# OPS       0.6350    0.015  41.440  0.000   0.605   0.665
# OBP       1.2543    0.101  12.427  0.000   1.056   1.452
# AB        4.8106    0.224  21.475  0.000   4.372   5.250

# %% [markdown]
# # Interpert Coefficient Values

# %% [markdown]
# ---

# %% [markdown]
# # Pitcher

# %%
# read in pitcher training data
pitcher_train = pd.read_csv('../Modeling_Data/pitcher_data_modeling.csv')
# read in batter testing data
pitcher_test = pd.read_csv('../Modeling_Data/pitcher_test_data.csv')

# %%
# set up X and y from training data
X = pitcher_train.drop(columns=['Name', 'Team', 'POS', 'PTS', 'AVG', 'FPPG'])
y = pitcher_train['FPPG']

# %%
# add constant
X = sm.add_constant(X)

# %%
# scale data
sc = StandardScaler()
# fit and transform X
X_sc = sc.fit_transform(X)

# %%
# GLM
glm_pitcher = sm.GLM(y, X_sc, family=sm.families.Poisson(link=sm.families.links.log())).fit()

# %%
results_summary = glm_pitcher.summary()

# %%
glm_pitcher.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   FPPG   No. Observations:                  760
# Model:                            GLM   Df Residuals:                      746
# Model Family:                 Poisson   Df Model:                           13
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -7819.2
# Date:                Mon, 10 May 2021   Deviance:                       12667.
# Time:                        17:49:55   Pearson chi2:                 1.57e+05
# No. Iterations:                     9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const               0          0        nan        nan           0           0
# x1            -0.0308      0.033     -0.942      0.346      -0.095       0.033
# x2            -0.0480      0.033     -1.475      0.140      -0.112       0.016
# x3            -1.9378      0.053    -36.836      0.000      -2.041      -1.835
# x4             1.0503      0.081     13.012      0.000       0.892       1.209
# x5             0.5868      0.038     15.491      0.000       0.513       0.661
# x6            -0.1359      0.125     -1.090      0.276      -0.380       0.108
# x7            -0.1360      0.109     -1.251      0.211      -0.349       0.077
# x8            -0.0454      0.159     -0.285      0.776      -0.358       0.267
# x9             0.7690      0.158      4.877      0.000       0.460       1.078
# x10            0.0233      0.036      0.644      0.520      -0.048       0.094
# x11            9.4863      2.205      4.302      0.000       5.164      13.809
# x12            0.1263      0.040      3.139      0.002       0.047       0.205
# x13           -0.7475      0.041    -18.185      0.000      -0.828      -0.667
# x14           -9.5005      2.198     -4.322      0.000     -13.809      -5.192
# ==============================================================================
# """

# %%
# create data frame of coefficients
# save as html
results_as_html = results_summary.tables[1].as_html()
# read in html
results_df = pd.read_html(results_as_html, header=0, index_col=0)[0]
# set index from X columns
results_df['Features'] = X.columns
results_df.set_index('Features', inplace=True)

# %%
# sort values
results_df.sort_values(by='coef')
# Out:
#             coef  std err       z  P>|z|  [0.025  0.975]
# Features
# WHIP     -9.5005    2.198  -4.322  0.000 -13.809  -5.192
# GMS      -1.9378    0.053 -36.836  0.000  -2.041  -1.835
# ERA      -0.7475    0.041 -18.185  0.000  -0.828  -0.667
# H        -0.1360    0.109  -1.251  0.211  -0.349   0.077
# IP       -0.1359    0.125  -1.090  0.276  -0.380   0.108
# L        -0.0480    0.033  -1.475  0.140  -0.112   0.016
# R        -0.0454    0.159  -0.285  0.776  -0.358   0.267
# W        -0.0308    0.033  -0.942  0.346  -0.095   0.033
# const     0.0000    0.000     NaN    NaN   0.000   0.000
# HR        0.0233    0.036   0.644  0.520  -0.048   0.094
# SO        0.1263    0.040   3.139  0.002   0.047   0.205
# SV        0.5868    0.038  15.491  0.000   0.513   0.661
# ER        0.7690    0.158   4.877  0.000   0.460   1.078
# GS        1.0503    0.081  13.012  0.000   0.892   1.209
# BB        9.4863    2.205   4.302  0.000   5.164  13.809

# %% [markdown]
# # Interpert
