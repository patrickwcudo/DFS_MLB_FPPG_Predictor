# %% [markdown]
# An attempt to pickel both models.

# %%
# IMPORTS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# modeling function import
from model import modeling_reg

# import metrics
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error

# imports for classifier
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, BaggingRegressor
from sklearn.tree import DecisionTreeRegressor

#import pickel
import pickle

# %%
# read in data for batters and pitchers
batters = pd.read_csv('../Modeling_Data/batter_data_modeling.csv')

# %%
# set X , y 
X = batters.drop(columns=['Name','Team','POS','FPPG', 'PTS'])
y = batters['FPPG']

# %%
# TTS
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
# linear regression
linreg = LinearRegression()

# %%
linreg.fit(X_train, y_train)

# %%
# .dump to save model above to file model.p
pickle.dump(linreg, open('model.p', 'wb'))

# %%
# check work
pickled_model = pickle.load(open('model.p', 'rb'))
# score
print(f'Score: {pickled_model.score(X_train, y_train):.2f}')
print(f'Score: {pickled_model.score(X_test, y_test):.2f}')
print(f'RMSE : {mean_squared_error(y_test, pickled_model.predict(X_test))}')
# Out:
# Score: 0.94
# Score: 0.88
# RMSE : 1.0402859482459252

# %%
# try predictions
testing = pd.read_csv('../CapStone_Data/FanDuel-MLB-2021 ET-05 ET-04 ET-58318-players-list.csv')

# %% [markdown]
# ## From here we need to merge this with the testing data, only information we need from this is the name, position, salary, team, game, etc
# ## Need stats for predictions.
# ## Use previous file

# %%
testing
# Out:
#                Id Position First Name           Nickname   Last Name  \
# 0     58318-52859        P      Jacob       Jacob deGrom      deGrom
# 1     58318-16956        P     Gerrit        Gerrit Cole        Cole
# 2     58318-82554        P      Shane       Shane Bieber      Bieber
# 3      58318-5481        P        Max       Max Scherzer    Scherzer
# 4     58318-82604        P     Corbin      Corbin Burnes      Burnes
# ..            ...      ...        ...                ...         ...
# 826  58318-137070        C     Joseph        Joseph Odom        Odom
# 827    58318-6005       OF       Matt         Matt Joyce       Joyce
# 828  58318-149374       SS       Sean    Sean Kazmar Jr.  Kazmar Jr.
# 829  58318-102284        C    William  William Contreras   Contreras
# 830   58318-12237        C   Jonathan    Jonathan Lucroy      Lucroy
#
#           FPPG  Played  Salary     Game Team Opponent Injury Indicator  \
# 0    61.600000     5.0   12500  NYM@STL  NYM      STL              NaN
# 1    54.166667     6.0   12200  HOU@NYY  NYY      HOU              NaN
# 2    55.666667     6.0   12000   CLE@KC  CLE       KC              NaN
# 3    42.166667     6.0   12000  ATL@WSH  WSH      ATL              NaN
# 4    49.600000     5.0   11100  MIL@PHI  MIL      PHI               IL
# ..         ...     ...     ...      ...  ...      ...              ...
# 826   0.000000     2.0    2000   TB@LAA   TB      LAA              NaN
# 827   2.494118    17.0    2000  MIL@PHI  PHI      MIL              NaN
# 828   0.000000     2.0    2000  ATL@WSH  ATL      WSH              NaN
# 829   9.500000     1.0    2000  ATL@WSH  ATL      WSH              NaN
# 830   5.000000     5.0    2000  ATL@WSH  WSH      ATL              NaN
#
#     Injury Details  Tier Probable Pitcher  Batting Order Roster Position
# 0              NaN   NaN              Yes            NaN               P
# 1              NaN   NaN              NaN            0.0               P
# 2              NaN   NaN              NaN            NaN               P
# 3              NaN   NaN              NaN            0.0               P
# 4      Undisclosed   NaN              NaN            0.0               P
# ..             ...   ...              ...            ...             ...
# 826            NaN   NaN              NaN            0.0       C/1B/UTIL
# 827            NaN   NaN              NaN            0.0         OF/UTIL
# 828            NaN   NaN              NaN            0.0         SS/UTIL
# 829            NaN   NaN              NaN            7.0       C/1B/UTIL
# 830            NaN   NaN              NaN            0.0       C/1B/UTIL
#
# [831 rows x 17 columns]

# %% [markdown]
# Going to need to do some cleaning for this file, use one that user would import.
